# %%
import pandas as pd
import numpy as np
import glob as gl
import networkx as nx
import os
import sys
import joblib
from sklearn.metrics import classification_report

# %%
id_handle_mapping_df = pd.read_table('./data/handle_id_mapping', delimiter='\t', names=['Handle'])
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: read_table is deprecated, use read_csv instead.
#   """Entry point for launching an IPython kernel.

# %%
id_handle_mapping_df.to_dict(orient='dict')
# Out:
# {'Handle': {1000000131100545029: 'wcartwrite',
#   1000000831: 'saxonfawn',
#   1000000884850483200: 'louiseauthenti1',
#   1000000927775019011: 'abdulha65061530',
#   1000000986046517248: 'lincsyngtories',
#   1000001060: 'amypashby',
#   1000001165260619776: 'niajacksonx',
#   1000001257329889280: 'cahill62509501',
#   1000001979060576256: 'neuswindon',
#   1000001985817411585: 'kriahnakumar12',
#   1000002127350165505: 'roymbotela9',
#   1000002140: 'donnasummer8',
#   1000002259: 'laurenjade995',
#   1000002300: 'tomrbond',
#   100000238: 'jessblaikie',
#   1000002456: 'wtc_careersteam',
#   1000002715999784961: 'boomersdgp4indy',
#   1000002836430811136: 'spendil09409108',
#   1000002906169446400: 'jamesro66722765',
#   1000003020690739201: 'murshhid',
#   1000003472: 'fionadempsey',
#   1000004096: 'vforvargdetta',
#   1000004489959563264: 'johndoe14883083',
#   1000004748681072640: 'zaherxrapidz1',
#   1000005028931874818: 'billcampbelltv',
#   1000005419115393025: 'alexgib26210754',
#   1000005677073477633: 'butsbuts100',
#   100000593: 'rob_phillips_',
#   1000006307305345025: 'aungchan011',
#   1000006542907924480: 'fabloel',
#   1000006546347225090: 'simonedemaso',
#   1000006547051831296: 'zeebkhan11',
#   1000006660419710977: 'sidheyho17',
#   1000007218291445760: 'papadoc94580666',
#   1000007498420584451: 'vman02017207',
#   1000007828155916290: 'emmamarienewma2',
#   1000007924129894401: 'enincx',
#   1000008111472758784: 'dakardo1',
#   1000008315072544768: 'xedaecexx',
#   1000008447004377089: 'libbywebb17',
#   1000008472505729024: 'arab26919252',
#   1000008648695930880: 'manipandya82',
#   1000008948336902145: 'blobdylan_',
#   1000009057284116486: 'rhoneybadger',
#   1000009064775147523: 'oscar_viklund',
#   1000009184577015809: 'vincentgosseli9',
#   1000009681: 'beakerknowles',
#   1000009882072993792: 'luigigm_yt',
#   1000010057743065089: 'sergio28469877',
#   1000010333321334784: 'takilaouami44',
#   1000010758506319872: 'vicssoul',
#   1000011197108965377: 'jessoslo',
#   1000011306: 'gem_kendall',
#   1000011412092080129: 'ilchidude',
#   1000011513481060354: 'caitmartin_16',
#   100001192: 'larrythelock',
#   1000012158200053760: 'vvc34720741',
#   1000012462622621698: 'sanjimaa',
#   1000012735562829825: 'boussedra8',
#   100001275: 'harrissey',
#   1000013018414092288: 'joaodcaldeira',
#   1000014714: 'mohamedzizooo66',
#   1000015089599037440: 'jaybang11',
#   1000015100550533120: 'adminjmc',
#   1000015147413450752: 'aiwauthenticdoc',
#   100001518: 'kurdistanisrael',
#   1000015221006610432: 'atravel01',
#   1000016571304173569: 'insideinfo_ru',
#   1000016689: 'lyndsaybennetts',
#   1000017139: 'jackhorrocks96',
#   1000017559041859586: 'sunshineiow',
#   1000017564: 'laul1989',
#   1000018657: 'bigbaz85',
#   1000018746612899840: 'sara_brusco',
#   1000018959272366080: 'markuskickflips',
#   1000019256: 'jacquiprocter',
#   1000019276: 'kimberleyroby',
#   1000019442569498624: 'worcseducation',
#   1000019510764691457: 'jezzacorbyn1',
#   1000020349: 'mageean17',
#   1000020630: 'fox_courtney16',
#   1000020710: 'notti_stefano',
#   1000020843957800961: 'archeofuturist0',
#   1000021511934300160: 'halil18401622',
#   1000021588996231168: 'danreed77',
#   1000021844: 'lyn_catrin',
#   1000021933: 'ms1164229',
#   1000022349599641602: 'sharonthandiacs',
#   1000022461: 'gazdenwhitt',
#   100002247: 'mohsbham',
#   1000022577530789888: 'clayshootingapp',
#   1000022848935809024: 'tbayfield',
#   1000023023364247552: 'davidch82223976',
#   1000023038: 'gregsy73',
#   1000023062: 'alandawes2',
#   1000023248116084736: 'pickandflick85',
#   100002329: 'barrymckech',
#   1000023427: 'willcocksjeremy',
#   1000023786475966465: 'steve96865280',
#   1000024005359947782: 'gdebarrahotmai1',
#   1000025611279261696: 'naqasha61569960',
#   100002573: 'dudeneyhelen',
#   1000026294283915265: 'watersidefestvl',
#   1000026573318361088: 'who_is_there_b',
#   1000026701437521928: 'the25297339',
#   1000026732567629825: 'kopanodesigns',
#   1000026798262976512: 'jrkisy',
#   1000027086: 'hamanumida',
#   1000027804296253443: 'elparce81725386',
#   1000028161034289155: 'bekzadah',
#   1000028491226771456: 'giorgothalassis',
#   1000028624605597697: 'gj2qn6mdmbkna8x',
#   1000028662756986881: 'rushinmedley',
#   1000028843569270784: 'jesssmbc',
#   1000029268250947584: 'ma03665811',
#   1000029407933882369: 'smith2charley',
#   1000029645276893184: 'lkr6z2jx5jtqjyy',
#   1000029791322451968: 'bluehorned',
#   1000029922595766272: 'vntaichinh',
#   1000029975414636545: 'mark01648809',
#   1000030001356517379: 'freedom48730372',
#   1000030070721966082: 'elonabasha92',
#   1000030423077085184: 'skillsjet',
#   1000030524: 'alanscott236',
#   1000030782403022849: 'planetlillie',
#   1000031039404855297: 'tracycommunity',
#   1000031187824463872: 'goatsaregreat6',
#   1000031204555612160: 'jbl_science',
#   1000031466: 'desimillar',
#   1000031841351557121: 'thomasy04487785',
#   1000031926030340096: 'lahey000',
#   100003193: 'pipinnaboix',
#   1000031997039988736: 'adhickscarpent1',
#   1000032267845230592: 'farmer10088838',
#   1000032338: 'uncharming_man',
#   1000032349990637570: 'boobthat',
#   1000032575027666949: 'matthew83319432',
#   1000032768439586816: 'bartlad69',
#   100003281: 'westlondonwine',
#   1000033202: 'bearnamedotis',
#   1000033638380122112: 'measteye',
#   1000034220981542912: 'galabarbara',
#   1000034527719444480: 'loverslamp',
#   1000034677347028992: 'chrismo62567433',
#   1000035078: 'emilymol02',
#   1000035218: 'dixonbuilding',
#   1000035513745715202: 'gemmanicholls12',
#   1000036130564268033: 'hardimanjohnny',
#   1000036166: 'martinhrabovec',
#   1000036263385280513: 'candace_412',
#   1000036279046758400: 'suraj37173672',
#   1000036521070735361: 'snappersandwell',
#   1000036603: 'n7slayer0',
#   1000036633: 'mikekenway',
#   1000036680030670848: 'rameshp19209583',
#   1000036762205544448: 'felipesaloojoc',
#   1000036886759596032: 'mirifairbrother',
#   1000036988: 'paddyshennan',
#   1000037166016335879: 'leetayl81472863',
#   1000037272278962176: 'tmcflooty',
#   1000037390684229632: 'merryrae2',
#   1000037845585842176: 'tehzeeb58544338',
#   1000037882919239680: 'wangkin32192701',
#   1000038399825166337: 'familiesskype',
#   1000038437175545857: 'shamim27565052',
#   1000038557665320960: 'cryptoalcon',
#   1000038888: 'fabzlawrence',
#   1000039248: 'mg_plastering',
#   1000039259708026883: 'mygrumpyhusban1',
#   1000039335436193792: 'kirstycommunity',
#   1000039522057498625: 'betterwaycredit',
#   1000039544: 'deniscullen2',
#   1000039572577947648: 'naomijmajor',
#   1000040074807984129: 'sytel_v',
#   1000040241040973824: 'pikinamba',
#   1000040418115969025: 'nazmuli37558760',
#   1000040468: 'stouglas',
#   100004063: 'andywashbourne',
#   1000040789949534210: 'jackgri20285989',
#   1000040827253649409: 'dogslies',
#   1000041645545574401: 'emmafrench3',
#   1000041814055968768: 'dannyallen19871',
#   1000041889305907200: 'romenfernandes',
#   1000043444180606978: 'ernest88651259',
#   1000043455685582848: 'lanefrog1',
#   1000043646262145024: 'chillizone2',
#   100004391: 'ross_phelan',
#   1000043976551026690: 'climatemuseumuk',
#   1000044012202594306: 'richardburke67',
#   1000044064316821504: 'paulinequigley5',
#   1000044406148354048: 'rafiubadekale',
#   1000044769: 'dvg_mufc',
#   1000045111793934337: 'ntifuse',
#   1000045654348099585: 'matthew16229327',
#   1000045698094649345: 'jilltaylorgarn2',
#   1000045820: 'antonellagrim',
#   1000045876176457730: 'irene00143542',
#   1000045931381702656: 'shahnazpervin10',
#   1000046012: 'zurma007786',
#   100004657: 'littlehillbill',
#   1000046639493533696: 'bowowow15',
#   100004676: 'occammamt',
#   1000046876: 'm4lik16',
#   100004705: 'perditastratton',
#   1000048276178063360: 'anurag58955940',
#   100004865: 'myboringhandle',
#   1000049329497878530: 'o2b_british',
#   1000049347: 'mikemix_uk',
#   1000049559287017478: 'willcoxmyles',
#   1000049846: 'caturdaynights',
#   1000050008: 'ahmadbi81744679',
#   1000050129951436800: 'wattawatty',
#   1000050574174380032: 'simonwa68015229',
#   1000050908762341376: 'mister____xxx',
#   1000051190422495238: 'armonazk',
#   1000051834147540992: 'nfu7hmsfreizqt9',
#   1000051835959472130: 'kgotsosekhute7',
#   1000051927: 'vishaltrip',
#   1000052222800158722: 'biddlestonsam',
#   1000052394569424897: 'gabrielsgonc',
#   1000052457106563072: 'wskksw23',
#   1000053459016708097: 'kevmufc44',
#   1000053674352300032: 'carlfirkin',
#   1000053692: 'masterfagan',
#   1000053696665980928: 'tranfo2030',
#   1000053867294294017: 'ahsan11547455',
#   1000053953135042561: 'samahanigh',
#   1000054056541474816: 'jomic75',
#   1000054146: 'penguinpeculiar',
#   1000054232660226051: 'votnoe',
#   1000054482292666369: 'peterkillelea',
#   1000054742968684551: 'haldrix2',
#   1000054761490698241: 'bruskyyyy',
#   1000054782835527681: 'v4n6gtahvappt48',
#   1000054927853604864: 'thecrescentnew1',
#   1000055091028725761: 'changingl1ves',
#   1000055237170860032: 'rauleu2',
#   1000055518210199552: 'em3hme',
#   1000055636535730177: 'alanjohnlondon',
#   1000055990: 'lianneebritton',
#   1000056214032732160: 'wwwtheviper75b',
#   100005654: 'leahkins1',
#   1000056863000588289: 'mccannjulie1',
#   1000056902427074560: 'tajhil900',
#   1000056985453322240: 'san_franciscofj',
#   1000057004214439936: 'mewithnoapology',
#   100005736: 'mongp',
#   1000057623348240384: 'sjeacott',
#   1000057926902599685: 'jay321081',
#   1000058006623711237: 'dawsonroxann',
#   1000058100261572608: 'lewis121uk1',
#   100005842: 'mccarthydinah',
#   1000058804: '16_gerry',
#   1000059306: 'guest4helen',
#   1000059350847762432: 'carlotion_san',
#   1000059378769235968: 'natalia40898844',
#   1000059429906153472: '_mairakhan',
#   100006011: 'martynode',
#   1000060328: 'jmateo909',
#   1000060610518896640: 'matteamerta',
#   1000060757105692672: 'danielemacr3',
#   1000061048517472257: 'stevewa96670716',
#   1000061238: 'bethaclark95',
#   1000061249126887424: 'petermcgrady1',
#   1000061488638414848: 'garycorrigan14',
#   1000062056614244352: 'gio_vengeance89',
#   1000062292795510784: 'felix22642743',
#   1000062479907639296: 'cpicton13',
#   1000062569711915008: 'matildeesrocha',
#   100006314: 'lindagump123',
#   1000063176321400833: 'vnurok',
#   1000063301555032064: 'youragencyone',
#   1000063407247298560: 'ianl09365742',
#   1000063477: 'nickhirst2',
#   1000063632342962176: 'sonny04604402',
#   1000064041883262976: 'natcjames',
#   1000064175396270085: 'hewgill_k',
#   1000064979184357376: 'jensenpastor',
#   1000065598989242374: 'monica_usa',
#   1000065867638489088: 'poojithraj2',
#   1000066137873420288: 'nakkuruzu2',
#   1000066593546801153: 'mariadocarmo_17',
#   1000066976: 'kanehowe94',
#   1000067456: 'geenz_a',
#   1000067515605798918: 'cameliabalihome',
#   100006776: 'iam0luapesinola',
#   1000068622499233792: 'tyburwill',
#   1000068645052125186: 'sodiusb',
#   1000068758281621504: 'gnomechomzki',
#   1000068859: 'vicrogo84',
#   1000069047176908802: 'edi397',
#   1000069420159467521: 'ubans3',
#   1000069477: 'rimshahrazzaq',
#   1000069482075869184: 'gnflanna',
#   1000069636380119040: 'jawad68204070',
#   100006965: 'psychicoracle',
#   100006996: 'astateofjiles',
#   100007027: 'scartw1',
#   1000070356651065344: 'patriciaatien17',
#   1000070993522712576: 'will_rhdyer',
#   1000071424311201792: 'popsmech',
#   1000071568268066817: 'freefromgamblin',
#   1000071877283500037: 'benforr34773580',
#   1000072168112295937: 'godhamaaryan',
#   1000072438322024455: 'sarah69082098',
#   1000072872746995713: 'mirab07461834',
#   1000073740900884480: 'soniakyle7',
#   1000073749960343552: 'mordy45509029',
#   100007382: 'nasirgabol_lfc',
#   1000074341835456512: 'babi36118461',
#   1000074422873657344: 'chirwayolam',
#   1000074573860212736: 'sadiqab25447021',
#   1000074748473364480: 'luigidiver86',
#   1000075036324192256: 'oxmailjamesr',
#   1000075063725522944: 'bilal90428478',
#   1000075075159281664: 'msubhab030481',
#   1000075212396859392: 'flaviopro25',
#   1000075351: 'gracey_72',
#   1000075544266932230: 'ryanbh1ll',
#   1000076025496293377: 'sopc19',
#   1000076334671040512: 'hassan99676702',
#   1000076354: 'andyrich37',
#   1000076574069272576: 'traceyj68179975',
#   1000077184633995264: 'md1816874',
#   1000077361533026305: 'johngreeves4',
#   1000077578: 'federicosaezp',
#   1000077921476861952: 'dlaurie12',
#   1000078508331294720: 'chisimbajoab',
#   1000078634462392322: 'rjpatterson1970',
#   1000078729: 'lufc_mac',
#   1000078982: 'tomwatto',
#   1000079012: 'leedsmith1984',
#   1000079032015376384: 'malikna29743578',
#   100007918: 'woodyuk69',
#   1000079564121493506: 'garnaith_bolgh',
#   1000079614134407169: 'murtaza_rahmani',
#   1000080019673305088: 'krah_wan',
#   1000080415397380096: '1967_ste',
#   1000080422: 'amirbhatti754',
#   1000080515351760897: 'davefau87358044',
#   1000080871460925445: 'deakyssmile',
#   1000080950: 'davidsnell16',
#   1000081017691168768: 'kittyfwerry',
#   1000081072665825280: 'trudibryant9',
#   1000081610: 'zfives',
#   1000081832: 'whydene',
#   1000082230700662784: 'armelli2',
#   1000082553674588165: 'cbazoto',
#   1000082824970596353: 'ishaq_samuel',
#   1000083290: 'shaneellis2018',
#   1000083513469800450: 'rexbechu',
#   1000083618931212288: 'wrighttoleft',
#   1000083633372319744: 'abnercesar4',
#   10000842: 'wjproctor',
#   1000085567013642241: 'elcomunista9',
#   1000085767681642496: 'chrisnash91',
#   1000085939715235845: 'jim73191428',
#   1000086025404846080: 'greengaged1',
#   1000086198: 'emsley66',
#   1000086315508125696: 'roryfly32203172',
#   1000086320713216000: 'jhon68831520',
#   1000086594316009472: 'anddrewv',
#   1000086649: 'payne_alexandra',
#   100008698: 'mms27',
#   1000087652467699714: 'btecmiawallace',
#   1000087945699905538: 'vmaaey',
#   1000088204354048000: 'tony86431708',
#   1000088391298535424: 'agabus43977432',
#   100008876: 'benjbentley',
#   1000089128254484480: 'annieapon',
#   1000089668673724417: 'frank53853595',
#   1000089934609440768: 'flexzee2',
#   1000089960068853760: 'jeanvdm5',
#   1000090586714648578: 'palbirb',
#   1000090684106428416: 'diane07502050',
#   1000090837374701568: 'j42doc',
#   1000090852226732034: 'truestcfc',
#   1000091027213049858: 'goldstarenglis1',
#   1000091475403735041: 'mohammedshiine',
#   1000091964526747648: 'digglerbarnes',
#   1000092107166625792: 'timstermr',
#   1000092277178621952: 'bec_jane97',
#   1000092434196500481: 'kemaltavus2',
#   1000092914: 'andyburley',
#   1000092960: 'bilsrye',
#   1000093364: 'samuels_ofeibea',
#   1000093444554088448: 'timesorwellian',
#   100009370: 'avuorenrinne',
#   1000094088: 'tom_long_',
#   1000095253309751296: 'tash09443538',
#   1000095900: 'sadiqshamyla',
#   1000096659089608705: 'slowgrindtime',
#   1000096679507480576: 'olivvia1477',
#   1000096703721156609: 'tguildford548',
#   1000096803600158724: 'stigler_hilmon',
#   1000096848370110465: 'markwil58189285',
#   1000097593: 'carlos_lock',
#   1000097645883547649: 'leeconstance43',
#   1000097727454351361: 'dannykozah',
#   100009779: 'txlonghorn956',
#   100009842: 'eduardogaral',
#   1000098553: 'leroy540',
#   1000098835081957378: 'greenhalgh_tony',
#   1000099027424284672: 'shereewilson78',
#   1000099047116541955: 'bono773',
#   1000099329191788545: 'hanna_burke2',
#   100009974: 'levi_jony',
#   1000100174: 'benconeyworth',
#   1000100354439155713: 'buckledill',
#   1000100710535630849: 'rose43571173',
#   1000100813484765185: 'arasbrk06',
#   1000100965125472256: 'shohag38745470',
#   1000101208672145413: 'grindflek1',
#   1000101499131789314: 'daniele07195518',
#   1000101716853907456: 'mr_lightnshadow',
#   1000101749376667648: 'drosfish',
#   1000101817005608960: 'sharjeelrajpu14',
#   1000102275497459719: 'hilderson12',
#   1000102351859081216: 'one_of_2genders',
#   1000102620592254976: 'barakziabdullah',
#   1000102996158578689: 'gallejeroen',
#   1000103037623525376: 'ahmedab53932851',
#   1000103281581023232: 'mihrap20011523',
#   1000103559516639235: 'redhead_matthew',
#   1000103573924073473: 'warforgedghost',
#   1000104144160673793: 'bernade90745839',
#   1000104758101721088: 'mdmahab59535360',
#   1000105201708208128: 'joannag86901982',
#   1000105380: 'porter_utf',
#   1000105418: 'waleemansour',
#   1000105542369636352: 'mazarhussain16',
#   1000105682: 'josephtracy82',
#   1000105695944069122: 'ytywhealthcare',
#   1000105704424923141: 'carolyne_endo',
#   1000105922222534656: 'dave71281505',
#   1000106144843685889: 'counterpolitics',
#   1000106263076900866: 'jonatha00198391',
#   1000106355682930694: 'juliemduncan1',
#   1000106558: 'dominictoland',
#   1000106685028028422: 'tebogo88919477',
#   1000107838071562241: 'eyambet',
#   1000108143517536256: 'henry87592035',
#   1000108243: 'ayb7861',
#   1000108385352732673: 'bethanyleff',
#   1000108742720086016: 'nat_breth15',
#   1000108800790159360: 'schwarzerfogel',
#   1000108855584534534: 'peter36921906',
#   1000109050539978752: 'ohitsnonbinary',
#   1000109403259846656: 'shadikkayem',
#   1000109471832690694: 'skully86086000',
#   1000109558835089408: 'jamesne30760415',
#   100010965: 'gossipcelebz',
#   1000109883591716864: 'northwestsouth2',
#   1000110254078640128: 'tennessee_pete',
#   1000110759236554752: 'bradianus',
#   100011092: 'borntodvlpbd',
#   1000111318760853505: 'abdifatahtayye',
#   1000111922: 'linosdrew',
#   100011228: 'ccartwright1971',
#   1000112293181468672: 'kev_stancet',
#   1000112563865210880: 'sorrel_tyhafan',
#   1000112807558500354: 'rubel45596662',
#   1000113009350627328: 'frans0407',
#   1000113085800214529: 'daiellicloudco1',
#   100011309: 'mukeshkapila',
#   1000113331: 'isaacdercks',
#   1000113765654949889: 'minkon5',
#   1000113911348236288: 'sedberghzero',
#   1000114118: 'chapmanmartine',
#   1000114227904958464: 'frankparry5',
#   1000114459: 'teamharingey',
#   100011468: 'jilaans',
#   1000114751173742593: 'ssashasimmons1',
#   1000114942249459713: 'leafe_daniel',
#   1000115248320282625: 'mpriyazabdulla',
#   1000115527690477573: 'nir01556471',
#   1000115888: 'estebanatuk',
#   1000116456162545664: 'samantha_copus',
#   1000116599947497473: 'ibrahim40547934',
#   1000116615747383297: 'jack29847818',
#   100011679: 'richardquinn1',
#   1000116955360256000: 'youngfortguru',
#   1000117200794079233: 'djallen94',
#   1000117283421937664: 'jobotwars',
#   1000117574: 'orihuela_nestor',
#   1000117770577743872: 'annesha63995456',
#   1000117777724837888: 'lynda_with_a_y_',
#   1000117949607350273: 'hadi_almtuf',
#   1000118147935100928: 'bartlebyyounger',
#   1000118230533406720: 'melissa46lock',
#   1000118240259997697: 'abdul_basitpti',
#   1000119158628077568: 'legoboukar',
#   1000119311703437312: 'slickerthe',
#   1000119330607165440: 'denizthe_menace',
#   1000119403076349952: 'brianmarvelfan1',
#   1000119437767438342: 'evanag1999',
#   1000119539345092610: 'greymiarp50',
#   1000119803019919363: 'ikramwaziristan',
#   1000119982896959491: 'razzwestcumbria',
#   1000121794983071744: 'marlene51191783',
#   100012186: 'thatcatloud',
#   1000122158: 'lee_inskip',
#   1000123630762815488: 'macdonaldgee',
#   1000123882538438658: '2020watcher',
#   1000123902826250240: 'themxfarmers',
#   1000124955881811968: 'dracus20',
#   1000124992854540290: 'jezmurray1',
#   1000125078: 'tobywoodcock',
#   1000125091: 'cmwoolmer',
#   1000125336120643585: 'charlieqie',
#   1000125427426430977: 'aworkfh',
#   1000126196: 'joesmith141414',
#   1000126219415932929: '_larawhite_',
#   1000126427319201793: 'carolmca1957gm1',
#   1000126724296904705: 'mr_morningsloth',
#   1000126794865897472: 'mohaamodyousuf',
#   1000126800155107328: 'kirsty01979',
#   1000126869625294849: 'rajaqai63305875',
#   1000126872968224768: 'olabodeakinleye',
#   1000126976823308288: 'giovann23865149',
#   100012708: 'alliotogo',
#   1000127341731950598: 'juliesi70721965',
#   100012788: 'bob2al1',
#   100012792: 'erinpattisonn',
#   1000128123655065602: 'hodlmymike',
#   1000128490669334528: 'awaismandor',
#   1000129211460407296: 'tmilla_23',
#   1000129512: 'paulgroves8',
#   1000129602: 'charliegrieve74',
#   1000129674696159232: 'lottiemair',
#   1000129809140379648: 'zaighamakram92',
#   1000130049650122752: 'kamalibrahimn',
#   100013034: 'mumma12345',
#   1000132022839496705: 'trumpylibertad',
#   1000132184131416064: 'alexand57384591',
#   1000132405632684032: 'william22200610',
#   1000132465: 'dalecrosbie',
#   1000132898299826176: 'pat_hibberd',
#   1000132988: 'claregollop',
#   1000133712: 'blobyn',
#   1000133985719259137: 'autisticstatis1',
#   100013416: 'abbieyaxley',
#   1000135285383065600: 'frog06102181',
#   1000136298378690560: 'shankha89289463',
#   1000136306129801216: 'qalmetari99',
#   100013710: 'luquinte',
#   1000137500952850433: 'jra17122494',
#   1000137696: 'drmisery107',
#   1000138062691799040: 'jamesma38008965',
#   1000138074947575808: 'jamesstanyer6',
#   1000138111714840577: 'banksjono',
#   1000138853943005184: 'fplcido1',
#   1000139303861833729: 'lozzie21318536',
#   1000139376087748608: 'aleksan32977493',
#   1000139610532515840: 'phabiusziggy',
#   1000139747577286661: 'davidnelsonnew1',
#   1000139821296254977: 'allanrayner4',
#   1000140137802723333: 'gwaze_trevor',
#   1000140271: 'danielareale3',
#   1000140639982510080: 'orrin_stella',
#   1000140829: 'chriskettle81',
#   1000140946204430341: 'realdylanmaher',
#   1000141203051110401: 'rav3goblin',
#   1000141318440579072: 'georgebobb4',
#   1000141532: 'taniaskae',
#   1000141939: 'm1n1nuge',
#   1000141982172401664: 'chris38587102',
#   1000142258749018112: 'greatvulpes',
#   1000143070237622274: 'ahmad_ibn_kalam',
#   1000143394662858753: 'bell55378638',
#   1000143842: 'thedeadestkid',
#   1000144195821146112: 'nawabshakeel2',
#   1000144292: 'whyteritchie',
#   1000144329804050435: 'deelou18',
#   1000145027945951232: 'yellowcrane92',
#   1000145775983185920: 'jamesantonell18',
#   1000145802315157504: 'alexjuanesteba1',
#   1000146486: 'rtierneyyy',
#   1000146607: 'adam_parker_man',
#   100014683: 'kitty_smith',
#   1000147039903207424: 'carlykeane101',
#   1000147140: 'sewageman1',
#   1000147207: 'geordiecopeland',
#   1000147273274146816: 'laxman_peri',
#   1000147359039401985: 'calogeromariano',
#   1000147627: 'lottie1180',
#   1000147855: 'd_melgoza',
#   1000148124: 'mosaenglish',
#   1000148543548674048: 'millgrist1',
#   100014861: 'oats4goats',
#   1000148673643405312: 'satnamtank',
#   1000148886030290946: 'karlinhafvalle',
#   1000149048979017728: 'masitete',
#   1000149196236840960: 'cnrkgh2809',
#   1000149761767477248: 'teddy_boy25',
#   1000150068: 'dgorman_',
#   1000150224: 'avalanchegeeks',
#   1000150884658036736: 'yeddi11',
#   1000151444: 'cely',
#   1000151590962106370: 'oski2507',
#   1000152196061782016: 'truthisreality1',
#   1000152566: 'djc80lfc',
#   1000153131412488192: 'reddit_cts',
#   1000153620724244480: 'mooncat48',
#   1000154037449195523: 'farhad51391401',
#   1000154530791739392: 'johncla46253302',
#   100015457: 'qa4hussain',
#   1000155114: 'laeccles1',
#   1000155368: 'bitcoinukmedia',
#   1000156124287586304: 'carvalho_marlus',
#   1000156613884370944: 'ramengayrl',
#   1000157218879221760: 'meslehmr',
#   1000157320645574658: 'nubes_por',
#   1000157587692769280: 'glentieselle',
#   1000158013787922432: 'rowbower',
#   1000158564: 'mudlubber',
#   1000158932697051137: 'duggertthomas',
#   1000159148: 'emski_co',
#   1000159902357245952: 'andrew49806731',
#   1000160398904057856: 'annalec92',
#   1000160522489286656: 'rolandlonda',
#   1000160868: 'missjohnston2',
#   1000161083414466562: 'ohdamnitsmari',
#   1000161180910895104: 'wallykenorukon',
#   1000161350465802241: 'annylaura10',
#   1000161498902253570: 'tod_wei',
#   1000161613: 'tommfcaylesbury',
#   1000161627700891649: 'skinnerr1579',
#   1000162032: 'mrslee1970',
#   1000162268: 'morethanmum1',
#   1000162476: 'lucyrowe16',
#   1000163143274790912: 'chrisvi39020376',
#   1000164878: 'ambrosemcnevin',
#   1000165092: 'beysstallion',
#   100016553: 'gallardo_ortega',
#   1000165790803410946: 'hullusasha',
#   1000166336: '69london',
#   1000166666418970624: 'pedrovictori_en',
#   1000167410396168193: 'basiltubail',
#   1000167572: 'linkzy_x',
#   1000167862227619840: 'jacobhatton7',
#   1000168088862674945: 'scorrahz1',
#   1000168278176788481: 'vote_d_not_r',
#   1000168513196249088: 'alfie_south',
#   1000168573522862080: 'thetroch',
#   1000168714019356672: 'beesong8',
#   1000168967296647168: 'ezatullahhelali',
#   1000168999739506688: 'angstepic',
#   1000169943311273985: 'nokaroh',
#   100017027: 'yuriquinones',
#   1000170394433695744: 'mustafa21738685',
#   1000171130647400448: 'mariamm74220796',
#   1000171682: 'freepilot3000',
#   1000173535132778496: 'youth8uk',
#   1000173546: 'dylthepickls',
#   1000173632: 'ageukcodurham',
#   1000173902130286593: 'haala_ly',
#   1000174052: 'charliellj',
#   1000174583570468869: 'candyf82219820',
#   1000175310: 'carrarosemary',
#   1000175341: 'claresned',
#   1000176081201172480: 'oftensharts',
#   1000176278: 'kahixo',
#   1000176445203861504: 'rafiullaharyan',
#   1000177064174018561: 'dodgeroseana',
#   1000177657: 'curtisjenks96',
#   1000177736038707201: 'iwantmycountry2',
#   1000179088772874241: 'davidco26378445',
#   100017919: 'vkatsardis',
#   1000179426246656000: 'johnbullbritish',
#   1000179626281525249: 'egalitariantwe',
#   1000179664147697664: 'diana07410158',
#   1000179949519564800: 'kristin42039785',
#   1000180868412043264: 'pap35074471',
#   1000181390: 'addiebundren',
#   1000182027939872768: 'pathextreme',
#   1000182037016383488: 'kingy781',
#   1000182048454131712: 'spikey7x',
#   1000182583: 'gboarders',
#   1000183155968573440: 'tsunamisarr',
#   1000183483019415552: 'opinion420',
#   1000183531866210305: 'jackkir22046441',
#   100018392: 'goode262',
#   1000184994768175104: 'lee01becky',
#   1000185805: 'borkbork_',
#   1000185865149255680: 'muhamma36653382',
#   1000185917674409986: 'goldbya',
#   1000186094: 'nick_jones74',
#   1000186194125295624: 'czesconsulting',
#   1000186507204870144: 'rebeccacarlyle9',
#   1000186595792699394: 'raphina21',
#   100018760: 'onuryildiz__',
#   1000187848358813696: 'ibrahimkhei',
#   1000188106891505665: 'awbp11',
#   1000188397: 'andrewdeckham',
#   1000189105173598208: 'noor15901521',
#   100018976: 'adiefletcher',
#   1000189939: 'realbeavis619',
#   100019106: 'mani_raziani',
#   1000192352: 'sonofidonia',
#   1000193587: 'abdo_mavrakis',
#   1000193665975779328: 'wwg1wg2020',
#   1000194272: 'heatherjanemary',
#   1000195272146747392: 'thomasguilty',
#   1000195902659850241: 'arushasiams',
#   1000196159665786880: 'marlonhaffely',
#   1000196485: 'danielgater2123',
#   1000197607: 'zaaaaiid',
#   1000197968: 'personalbestncs',
#   1000198020464627712: 'persianfoot1',
#   1000199203434500098: 'angelah72103293',
#   1000200573273112577: 'abbas18949622',
#   100020128: 'mikesavery',
#   1000202071: 'markdj59',
#   1000202141800259589: 'akhan1210',
#   1000202977674702848: 'hellowo94328185',
#   1000204116: 'nyorkstrinity',
#   1000204278: 'sherry_kat',
#   1000204974: 'ayembusimam',
#   1000205569: 'itxmeeeee',
#   1000205725660938241: 'hindusahabji',
#   1000205792: 'sankeyterry',
#   100020605: 'ellersman',
#   1000206057476632576: 'bearfeednews',
#   1000206284: 'alihass35074117',
#   1000206758: 'paul_trudgian',
#   1000206919829676032: 'shelbyglas',
#   1000208526: 'brooke_wardx',
#   1000210844: 'milly_thomas1',
#   1000211784: 'ahmedmeiloud',
#   1000211791107055616: 'c8lindonnelly',
#   1000213178: 'trinidadchainz',
#   100021329: 'lillysthomas',
#   1000214329931849729: 'mi_prisco',
#   1000215016099008514: 'littlecashew3',
#   1000215310127874049: 'anon53803633',
#   1000215380: 'asmus28',
#   1000215450: 'johngreer40',
#   100021577: 'bargee48',
#   1000215815365545984: 'lukemouton',
#   1000215901: 'aliseaashby',
#   1000217348: 'elizcoughlan',
#   100021803: 'hsctraininglink',
#   1000218296: 'carolkaraca',
#   100021841: 'sssgoraya',
#   1000218518472871936: 'hunna24793118',
#   1000218726086643712: 'chachimps',
#   1000218920: 'bri1978brian',
#   1000219014: 'sineadmac13',
#   1000219158649303040: 'saran21472359',
#   100021967: 'tetuayo',
#   1000220732: 'mickysure4u',
#   1000221260: 'tasneem_aziz',
#   1000222782678958080: 'golddingleberry',
#   1000223083: 'irishrebeltim',
#   1000223200381304833: 'siddiquetaufiq',
#   100022364: 'markbisson',
#   1000223730877034498: 'headpool_r2r',
#   1000224019: 'bendonaldson6',
#   1000224780753174528: 'rem_finlande',
#   1000225405020917760: 'nishan52072912',
#   100022597: 'anaiya_atkinson',
#   1000228238: 'adwooldridge',
#   1000228241209249794: 'jupi24erjazz',
#   1000228661033762818: 'ashishg82400175',
#   1000228849: 'danimaltime',
#   1000229043382317056: 'lordassasin_',
#   100022933: 'parkavenueguy',
#   1000229443401633792: 'malakfaizan4',
#   1000229567074795520: 'iliviedavictor',
#   1000229797: 'smorgs2012',
#   1000229839: 'rutherarts',
#   1000229942020341761: 'aryanra89175343',
#   1000230432900820992: 'simonygarfunkel',
#   100023070: 'alyoshabarnes',
#   1000231731868372992: 'jelle02114915',
#   1000231788: 'maxhzi9',
#   1000232186765873153: 'mcmakhanyah',
#   1000233577068613634: 'klmyerimaknae',
#   1000233893562343424: 'capmahmoud22',
#   100023418: 'fazallab',
#   1000234700596707328: 'comeandtakeit2a',
#   1000234856683487233: 'nain56596221',
#   100023580: 'svnickbarg',
#   100023698: 'craddod',
#   1000238813480972290: 'chasendreams85',
#   1000238899: 'caroline_rogan',
#   100023916: 'lorenzatl',
#   100023947: 'ames_tweet',
#   1000239664937095169: 'khushbootawde2',
#   100024085: 'vera_bergkamp',
#   1000241359423451137: '978dan1',
#   1000241497: 'kerradoylexo',
#   1000242212020670465: 'pipalno1',
#   1000242805321723905: 'xmichd',
#   100024321: 'katiestepek',
#   1000244205933936640: 'being_balakumar',
#   1000246639838183424: 'turn_rightonred',
#   1000247541663911936: 'lona99574012',
#   1000247691983679489: 'jotang8',
#   1000247774204563457: 'annanghauri',
#   1000248134: 'darryllgarland',
#   1000248676823064577: 'felixohagan3',
#   100024942: 'softfui',
#   1000250340913106946: 'sammbenton',
#   1000250360886448129: 'jchenchuyu',
#   100025085: 'trassens',
#   1000251433428639744: 'rollsos',
#   1000251739: 'gradynt',
#   1000252148: 'justkateyea',
#   1000252237: 'solihullphotsoc',
#   100025227: 'damvalens',
#   1000252584: 'leeleeroses',
#   1000253046: 'cptnamerico',
#   1000253172261244928: 'bob_clubtelford',
#   100025340: 'garrett_carr',
#   1000254792: 'brianmarsh52',
#   1000255260: 'orlandarosario',
#   1000255321430867970: 'naveen_polina',
#   100025559: 'mohammadhoseini',
#   1000256183712829440: 'jamesno82316664',
#   1000257210: 'tahmidakthar',
#   100025743: 'marioonaladder',
#   1000257872: 'leygeee',
#   1000258449509404672: 'winona_bartle',
#   1000258519533309952: 'kotik75438535',
#   1000259149: 'danny_hinson',
#   1000259152806105088: 'emgemoh',
#   1000259680550244353: 'jasonwigeordie',
#   100026017: 'meashii',
#   1000261723163648000: 'stephen04702351',
#   1000261884: 'ncpmatuh',
#   1000263301182476289: 'milestunhi',
#   1000263456505913344: 'ammar81669660',
#   1000263951668559872: 'ishuraja2',
#   100026400: 'moxyfruzy',
#   1000264367244435456: 'ora_chem',
#   1000264746149470208: 'alexsha23184281',
#   1000264769096568832: 'mgsalmaso',
#   100026487: 'rebeccamaywelsh',
#   1000264926773022720: 'tqz7w37sqg4n069',
#   1000266338559029249: 'uqailishafique',
#   1000266540: 'pumainvineguer',
#   1000266606876987392: 'stbakbures',
#   1000266974826381312: 'canadawcai',
#   1000267059815739397: '9xaxyuqm4mtm04i',
#   1000267471: 'mrstephencasey',
#   1000267585: 'vgoochi',
#   1000268400596340736: 'rebecca39738424',
#   1000268485: 'lee_garwood',
#   100026918: 'chrisbirchfmx',
#   1000269220612014081: 'natasha51200887',
#   1000269271: 'zoilita1997',
#   1000269651211767808: 'amanda_melb999',
#   1000270296: 'meg_mooch',
#   1000270615104966657: 'coombesles',
#   100027109: 'emblackshaw',
#   1000271522894958597: 'kmeiix',
#   1000271800679522304: 'hells00731639',
#   1000272155177816064: 'mcgaleoliver',
#   1000272284165197826: 'zjqid2o5rqmc5vw',
#   1000273255: 'bebopshock',
#   1000273468556967936: 'sana_khan33',
#   1000273831758581760: 'susiemu64462733',
#   1000274040: 'chrisbogavin',
#   1000274248605356032: 'coleridge_tim',
#   1000275082344828928: 'thenomadteache1',
#   100027688: 'catmcg',
#   1000277059: 'airhog91',
#   1000277341: 'wendytbailey',
#   1000277530778140672: 'danielbryant03',
#   1000277621123399681: 'amandeepchhin12',
#   100027770: 'bonamarcio',
#   1000278168119533570: 'joncampey',
#   1000278271: 'colinwelwyn',
#   1000278318: 'tmwentz',
#   1000279492940746754: 'sam94990942',
#   1000279613447254016: 'pv15667067',
#   1000279849: 'humdrumdave',
#   100027989: 'danthebusker',
#   1000281308: 'willington_hall',
#   1000281330: 'staceyfieldhous',
#   1000282307947720707: 'corybookker',
#   1000282441846845441: 'stephenhussein',
#   1000282509475811328: 'hafizhaseebit',
#   1000282837: 'catherine_oakes',
#   100028313: 'guido4',
#   1000283167608266752: 'cosimopirogmai1',
#   1000283661214932992: 'nichollrosie',
#   1000284407373139968: 'nosko_martin',
#   1000284469: 'leegammon',
#   100028488: 'chriswhufc107',
#   10002852: 'scala',
#   1000285958: 'craigthompson85',
#   1000287572885581824: 'under_armourwwe',
#   1000288117235044352: '1545hours',
#   1000288457359527937: 'ayigbenew',
#   1000288679909244928: 'hannah47359314',
#   1000289028: 'qariasim',
#   1000289045904347137: 'r10gwj1',
#   1000289196639211520: 'obaidullahdarw2',
#   1000289358207995904: 'jonny_byron',
#   1000289990251761664: 'higuchit2',
#   1000290500623130624: 'easthertsradio',
#   1000290582: 'sophiectweets',
#   1000291308928471041: 'princessgmail14',
#   1000291860081008640: 'sjpurslow',
#   100029247: 'sharonjardine',
#   100029349: 'aidmcquaid',
#   1000294085775839233: 'george2o19',
#   1000294672864964608: 'iamtharakaw10',
#   1000294932211527680: 'benverdes',
#   100029550: 'karenchamie',
#   1000295749744254976: 'grossmannnadja',
#   1000295812205867008: 'sad80170591',
#   1000296237520900096: 'barbaracooney9',
#   1000296546523496448: 'raokhan7351823',
#   1000297256967393280: 'louispgill',
#   1000297704147308544: 'enercamp1',
#   100029807: 'stesin99uk',
#   1000298100: 'bnooryani',
#   1000298208315179008: 'namethisbook',
#   1000298234147934209: 'assoccritlaw',
#   1000298720330731521: 'son_amba',
#   1000300202: 'applecross100',
#   1000300222898212864: 'delccris',
#   1000300227537010689: 'subliminalsubv1',
#   1000300269773774848: 'truevult',
#   1000300968645419008: 'davebadillo73',
#   1000301254654996482: 'tracyta40960315',
#   1000301823130062849: 'alsantoli',
#   1000302192354525184: 'senglish36',
#   1000302318330503168: 'charlie62215216',
#   1000302536: 'chloewray13',
#   100030327: 'iyce_iyce_baby',
#   1000303333: 'nicholsutd',
#   1000303508887924737: 'mrbrexit4',
#   1000303558355537920: 'rowan_whitelock',
#   1000303611866476544: 'whysupofficial',
#   1000303662151995392: 'ugochukwuon',
#   100030562: 'reynardinefox',
#   1000305855970074625: 'otaernest',
#   1000306729098334208: 'pauline36873731',
#   1000306820982984710: 'ahmaddi_muslim',
#   1000307714944204806: 'omniwil',
#   1000308143342186496: 'daisy_banned',
#   1000308202641256448: 'zemeckis11',
#   1000308464: 'brynrockytaylor',
#   1000308752803909632: 'oakbedford',
#   1000308827848396802: 'pkubondo',
#   1000308886182813696: 'andyglasgow6',
#   1000309301288800256: 'imdanferguson',
#   1000309485796241408: 'ewssociology',
#   1000309633884573698: 'joelleparisusa1',
#   1000309928698015745: 'adialessia_',
#   1000310179: 'janibarber',
#   100031022: 'abiwilsonn',
#   1000310282785259520: 'lukeshiundu3',
#   1000310464373575680: 'b90613386',
#   1000310504311619584: 'kevin36652628',
#   100031073: 'stephicampbell',
#   1000311080: 'carljbodman',
#   1000311657376243712: 'jcavellwriter',
#   1000312323960180736: 'stuartemms',
#   1000312351: 'claudia_buck2',
#   1000312819642908672: 'sinopiaskunk',
#   1000313186418077703: 'newhamcons',
#   1000313503608180739: 'sagalaayyspeaks',
#   1000314314270666752: 'pukkapure',
#   100031444: 'andy_simms',
#   1000314504: 'floragoodfellow',
#   1000314809521500162: 'prabak23270561',
#   1000315237: 'puffin32',
#   100031533: 'everythingisrad',
#   1000315758: 'haseena_20',
#   1000315830: 'spokey_doke',
#   1000315836: 'darrienjustice',
#   1000316163342176258: 'georgehindikos',
#   1000316196758188033: 'mdl4290',
#   10003162: 'edelman_br',
#   1000316617853751296: 'muhamme92328446',
#   1000316981097238530: 'callum_willzy',
#   1000317266360176640: 'youngbl71091205',
#   1000317363869376512: 'johnsmi43709959',
#   1000318145008226304: 'mrweatherby_ehu',
#   1000318302789480448: 'titilayo___',
#   1000318392: 'sms19661',
#   1000318562601496576: 'kinspireinson',
#   1000318717: 'chrismilne11',
#   1000318884111667201: 'lion_alliance',
#   1000318924095827968: 'tanvira69779558',
#   1000318974318596096: 'timcroft8',
#   1000319117885345792: 'nour07321801',
#   1000319408: 'sophieobuckley',
#   1000319452817354752: 'davidjshoop1',
#   1000319800894197761: 'amy64883734',
#   1000319827: 'anylittlecity',
#   1000319958847500288: 'gwrfc_official',
#   1000320277400772608: 'existingini',
#   1000320795888046081: 'lee35438562',
#   ...}}

# %%
def print_progress(iteration, total, prefix='', suffix='', decimals=1, length=100):

    str_format = "{0:." + str(decimals) + "f}"
    percents = str_format.format(100 * (iteration / float(total)))
    filled_length = int(round(length * iteration / float(total)))
    bar = '*' * filled_length + '-' * (length - filled_length)

    sys.stdout.write('\r%s |%s| %s%s %s' % (prefix, bar, percents, '%', suffix)),

    if iteration == total:
        sys.stdout.write('\n')
    sys.stdout.flush()

# %% [markdown]
# ## Generate Full Follower Graph

# %%
path = './followers/*.txt'

files = gl.glob(path)

j = 0

g = nx.Graph()

for f in files:
    mp_df = pd.read_csv(f, names=['handle'])
    base = os.path.basename(f)
    mp = os.path.splitext((base))[0].lower()
    handle_mapping_dictionary = id_handle_mapping_df.to_dict(orient='dict')
    for v in handle_mapping_dictionary.values():
        handle_mapping_dictionary = v
    print_progress(j + 1, 579, prefix='Progress:', suffix='Complete')
    follower_list = []
    
    for ele in list(mp_df.values):
        if ele[0] not in g:
            if handle_mapping_dictionary.get(ele[0]) is not None:
                follower_list.append(handle_mapping_dictionary.get(ele[0]).lower())

    j += 1
    l = [mp]
    if l[0] not in g:                         
        node_list = l + follower_list
        tail = node_list
        tail.pop(0)

    else:
        node_list = follower_list
        tail = node_list
        
    g.add_nodes_from(node_list)
                                 
    edge_list = []

    for h in tail:
        edge_list.append((mp, h))

    g.add_edges_from(edge_list)
# Out:
# Progress: |████████████████████████████████████████████████████████████████████████████████████████████████████| 99.8% Complete

# %% [markdown]
# ## Generate MP Only Follower Graph

# %%
mp_list_names = []

path = './followers/*.txt'

files = gl.glob(path)

for f in files:
    base = os.path.basename(f)
    mp = os.path.splitext((base))[0].lower()
    mp_list_names.append(mp)

# %%
path = './followers/*.txt'

files = gl.glob(path)

j = 0

g = nx.Graph()

for f in files:
    mp_df = pd.read_csv(f, names=['handle'])
    base = os.path.basename(f)
    mp = os.path.splitext((base))[0].lower()
    handle_mapping_dictionary = id_handle_mapping_df.to_dict(orient='dict')
    for v in handle_mapping_dictionary.values():
        handle_mapping_dictionary = v
    print_progress(j + 1, 579, prefix='Progress:', suffix='Complete')
    follower_list = []
    
    for ele in list(mp_df.values):
        if ele[0] not in g:
            if handle_mapping_dictionary.get(ele[0]) is not None:
                if handle_mapping_dictionary.get(ele[0]) in mp_list_names
                    follower_list.append(handle_mapping_dictionary.get(ele[0]).lower())

    j += 1
    l = [mp]
    if l[0] not in g:                         
        node_list = l + follower_list
        tail = node_list
        tail.pop(0)

    else:
        node_list = follower_list
        tail = node_list
        
    g.add_nodes_from(node_list)
                                 
    edge_list = []

    for h in tail:
        edge_list.append((mp, h))

    g.add_edges_from(edge_list)

# %%
labels = joblib.load('./all_new_2019_brexit_vote_labels.y')
# Out:
# {'label': 1, 'score': 1}

# %%
import random
from sklearn.metrics import classification_report
from random import randrange

random.seed(17)

for n in g.nodes:
    g.node[n]['label'] = None

for k in labels.keys():
    g.node[k]['label'] = labels.get(k)

def initialize_scores(G, init_value):
    for node_id in G.nodes():
        label = G.node[node_id]['label']
        if label == 0:
          # Labeled nodes: RED
          G.node[node_id]['score'] = 0
        elif label == 1:
          # Labeled nodes: BLUE
          G.node[node_id]['score'] = 1
        else:
          # Unlabeled nodes
          G.node[node_id]['score'] = init_value
        
def calculate_avg_score(G, node_id):
  score_sum = 0
  n_neighbors = 0
  for neighbor_id in G[node_id]:
    if G.node[neighbor_id]['score'] is not None:
        score_sum += G.node[neighbor_id]['score']
        n_neighbors += 1
  return score_sum / n_neighbors

def propagate(G):
  next_scores = {}
  for node_id in G.nodes():
    if G.node[node_id]['label'] is not None:
      # scores of labeled nodes do not change
      next_scores[node_id] = G.node[node_id]['score']
    else:
      next_scores[node_id] = calculate_avg_score(G, node_id)
  for node_id in next_scores:
    G.node[node_id]['score'] = next_scores[node_id]

test = list(labels.values())
random_index = []
nodes

seed_ = 57
count = 0
while count < seed_nodes:
    x = randrange(len(test))
    if x not in random_index:
        random_index.append(randrange(len(test)))
        count += 1


mp_handles_keys = list(labels.keys())

for i in random_index:
    g.node[mp_handles_keys[i]]['label'] = None
    g.node[mp_handles_keys[i]]['score'] = None

initialize_scores(g, 0.5)
n_steps = 6
for i in range(n_steps):
    propagate(g)

final_predicted_scores = []

for i in random_index:
    x = g.node[mp_handles_keys[i]]['score']
    if x < 0.5:
        final_predicted_scores.append(0)
    else:
        final_predicted_scores.append(1)
        
actual_scores = []
for i in random_index:
    actual_scores.append(labels.get(mp_handles_keys[i]))

print(classification_report(actual_scores, final_predicted_scores, labels=[0,1]))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99        62
#            1       0.98      1.00      0.99        52
#
#     accuracy                           0.99       114
#    macro avg       0.99      0.99      0.99       114
# weighted avg       0.99      0.99      0.99       114

# %%
degrees = [(node,val) for (node, val) in g.degree()]
sorted(degrees, key=lambda x: x[1], reverse=True)
# Out:
# [('jeremycorbyn', 1256551),
#  ('nigel_farage', 829721),
#  ('theresa_may', 658149),
#  ('ed_miliband', 545038),
#  ('borisjohnson', 361083),
#  ('davidlammy', 306628),
#  ('chukaumunna', 282513),
#  ('carolinelucas', 272859),
#  ('yvettecoopermp', 198349),
#  ('tom_watson', 181507),
#  ('hackneyabbott', 176963),
#  ('timfarron', 153290),
#  ('johnmcdonnellmp', 147179),
#  ('emilythornberry', 132893),
#  ('harrietharman', 130489),
#  ('vincecable', 121081),
#  ('mhairiblack', 109717),
#  ('jacob_rees_mogg', 106764),
#  ('hilarybennmp', 100291),
#  ('lucianaberger', 95020),
#  ('angelarayner', 94470),
#  ('michaelgove', 92592),
#  ('keir_starmer', 82929),
#  ('philiphammonduk', 82404),
#  ('andrealeadsom', 81476),
#  ('amberruddhr', 77542),
#  ('jessphillips', 77435),
#  ('leicesterliz', 75850),
#  ('jeremy_hunt', 75258),
#  ('sajidjavid', 73286),
#  ('liamfox', 71578),
#  ('stellacreasy', 70555),
#  ('labourlewis', 68327),
#  ('tulipsiddiq', 67689),
#  ('owensmith_mp', 65322),
#  ('anna_soubry', 63130),
#  ('rachelreevesmp', 62001),
#  ('angelaeagle', 61723),
#  ('zacgoldsmith', 61477),
#  ('justinegreening', 61471),
#  ('barrygardiner', 61318),
#  ('grantshapps', 59197),
#  ('lisanandy', 56698),
#  ('pennymordaunt', 55570),
#  ('katehoeymp', 53893),
#  ('patel4witham', 53840),
#  ('johnnymerceruk', 53757),
#  ('daviddavismp', 52104),
#  ('carolineflintmp', 51582),
#  ('jonashworth', 51390),
#  ('dominicraab', 51340),
#  ('nsoames', 51038),
#  ('thomasbrake', 50433),
#  ('joswinson', 49859),
#  ('rhonddabryant', 49512),
#  ('danjarvismp', 49462),
#  ('trussliz', 48734),
#  ('dawnbutlerbrent', 48730),
#  ('joannaccherry', 47867),
#  ('laurapidcockmp', 47838),
#  ('stevebakerhw', 47429),
#  ('derbychrisw', 47149),
#  ('johnredwood', 45659),
#  ('nickymorgan01', 44222),
#  ('nadinedorries', 43775),
#  ('nickboles', 43735),
#  ('ianblackfordmp', 42145),
#  ('chrislesliemp', 41888),
#  ('jamescleverly', 41705),
#  ('andreajenkyns', 40280),
#  ('normanlamb', 39712),
#  ('alison_mcgovern', 39090),
#  ('lucympowell', 38995),
#  ('richardburgon', 38988),
#  ('brandonlewis', 38688),
#  ('benpbradshaw', 38430),
#  ('gloriadepiero', 38404),
#  ('tobias_ellwood', 38115),
#  ('sarahwollaston', 37745),
#  ('meaglemp', 37426),
#  ('sarahchampionmp', 36737),
#  ('esthermcvey1', 35940),
#  ('mikegapes', 35502),
#  ('gwynnemp', 35297),
#  ('drrosena', 35087),
#  ('ianlaverymp', 35084),
#  ('samgyimah', 33645),
#  ('marycreaghmp', 33633),
#  ('laylamoran', 33360),
#  ('margarethodge', 32718),
#  ('petewishart', 32619),
#  ('edvaizey', 32328),
#  ('rorystewartuk', 32165),
#  ('wesstreeting', 31842),
#  ('rupahuq', 31577),
#  ('jwoodcockmp', 31012),
#  ('johnpenrosenews', 30960),
#  ('jreynoldsmp', 30804),
#  ('stephentwigg', 30209),
#  ('jojohnsonuk', 30158),
#  ('damianhinds', 29949),
#  ('debbie_abrahams', 29799),
#  ('chionwurah', 29397),
#  ('owenpaterson', 28614),
#  ('angelasmithmp', 28460),
#  ('louiseellman', 28333),
#  ('tracey_crouch', 28080),
#  ('catsmithmp', 27912),
#  ('mike_fabricant', 27495),
#  ('kategreensu', 27464),
#  ('angusmacneilsnp', 27216),
#  ('liambyrnemp', 27005),
#  ('louhaigh', 26823),
#  ('rushanaraali', 26685),
#  ('johnmannmp', 25859),
#  ('edwardjdavey', 25544),
#  ('geoffrey_cox', 25209),
#  ('drphillipleemp', 24877),
#  ('peterboneuk', 24824),
#  ('kerrymp', 24627),
#  ('tommysheppard', 24602),
#  ('bernardjenkin', 24316),
#  ('damiancollins', 24010),
#  ('gregclarkmp', 23816),
#  ('greghands', 23235),
#  ('stewartmcdonald', 23014),
#  ('tracybrabin', 22801),
#  ('grahamemorris', 22790),
#  ('halfon4harlowmp', 22612),
#  ('stevereedmp', 22550),
#  ('nadhimzahawi', 22519),
#  ('frankfieldteam', 22439),
#  ('johnhealey_mp', 22290),
#  ('jbrokenshire', 22266),
#  ('bphillipsonmp', 22056),
#  ('georgefreemanmp', 21814),
#  ('hbaldwin', 21778),
#  ('karlturnermp', 21731),
#  ('liliangreenwood', 21602),
#  ('skinnock', 21458),
#  ('sharonhodgsonmp', 21371),
#  ('stewarthosiesnp', 21272),
#  ('catherinewest1', 21250),
#  ('alistairburtuk', 21233),
#  ('ianmearnsmp', 21212),
#  ('heidiallen75', 21066),
#  ('abridgen', 20769),
#  ('nazshahbfd', 20675),
#  ('tomtugendhat', 20585),
#  ('keeleymp', 20491),
#  ('catmckinnell', 20153),
#  ('hammersmithandy', 20045),
#  ('alisonthewliss', 19781),
#  ('scrabbpembs', 19776),
#  ('dianajohnsonmp', 19630),
#  ('dlidington', 19344),
#  ('kateosamor', 19309),
#  ('emmareynoldsmp', 19272),
#  ('jackdromeymp', 19254),
#  ('dr_philippaw', 19224),
#  ('alanduncanmp', 18998),
#  ('seemamalhotra1', 18949),
#  ('mpphilwilson', 18682),
#  ('nigeldoddsdup', 18655),
#  ('robertabwmp', 18611),
#  ('vernon_coaker', 18583),
#  ('marshadecordova', 18348),
#  ('rachaelmaskell', 18084),
#  ('lloyd_rm', 17964),
#  ('paulasherriff', 17963),
#  ('hannahb4livimp', 17933),
#  ('dancardenmp', 17714),
#  ('anncoffey_mp', 17632),
#  ('gavinshuker', 17535),
#  ('patmcfaddenmp', 17466),
#  ('tobyperkinsmp', 17202),
#  ('laurasmithmp', 17180),
#  ('helengoodmanmp', 17147),
#  ('nickhurduk', 17097),
#  ('thangammp', 17037),
#  ('jimfromoldham', 16886),
#  ('joanryanenfield', 16791),
#  ('philipdaviesuk', 16599),
#  ('coyleneil', 16593),
#  ('afzal4gorton', 16536),
#  ('suellabraverman', 16534),
#  ('andymcdonaldmp', 16503),
#  ('kirstysnp', 16500),
#  ('joncruddas_1', 16400),
#  ('ianmurraymp', 16367),
#  ('mariamilleruk', 16175),
#  ('jon_trickett', 16092),
#  ('bill_esterson', 16027),
#  ('stevebarclay', 15838),
#  ('paulblomfieldmp', 15814),
#  ('sdoughtymp', 15813),
#  ('juliansmithuk', 15762),
#  ('ruthcadbury', 15746),
#  ('shabanamahmood', 15745),
#  ('cskidmoreuk', 15734),
#  ('jostevenslabour', 15671),
#  ('ruthsmeeth', 15619),
#  ('lukepollard', 15595),
#  ('johnglenuk', 15595),
#  ('darrenpjones', 15561),
#  ('conorburnsuk', 15559),
#  ('yasminqureshimp', 15460),
#  ('kevanjonesmp', 15410),
#  ('cmonaghansnp', 15133),
#  ('julieelliottmp', 15056),
#  ('robertbuckland', 15038),
#  ('davidhansonmp', 15016),
#  ('annemariemorris', 15016),
#  ('richardburdenmp', 14907),
#  ('danielzeichner', 14886),
#  ('billcashmp', 14874),
#  ('theresecoffey', 14713),
#  ('andrewselous', 14677),
#  ('meg_hilliermp', 14611),
#  ('stephengethins', 14560),
#  ('chhcalling', 14543),
#  ('markfielduk', 14537),
#  ('cj_dinenage', 14469),
#  ('annaturley', 14438),
#  ('chrislawsnp', 14405),
#  ('mattwarman', 14319),
#  ('ianaustinmp', 14316),
#  ('jesse_norman', 14308),
#  ('dkshrewsbury', 14296),
#  ('justintomlinson', 14293),
#  ('siobhain_mp', 14251),
#  ('damiangreen', 14164),
#  ('helenhayes_', 14127),
#  ('stuartandrew', 13978),
#  ('charlieelphicke', 13895),
#  ('timloughton', 13868),
#  ('andrew4pendle', 13864),
#  ('acunninghammp', 13823),
#  ('sheryllmurray', 13692),
#  ('kevinbrennanmp', 13691),
#  ('lizmcinnes_mp', 13678),
#  ('heatherwheeler', 13548),
#  ('hugoswire', 13541),
#  ('norwichchloe', 13539),
#  ('niagriffithmp', 13430),
#  ('pauline_latham', 13407),
#  ('preetkgillmp', 13319),
#  ('davidtcdavies', 13263),
#  ('emmadentcoad', 13234),
#  ('ivanlewis_mp', 13210),
#  ('j_donaldson_mp', 13194),
#  ('steve_mccabe', 13154),
#  ('mgreenwoodww', 13132),
#  ('mtpennycook', 13098),
#  ('jakeberry', 13095),
#  ('andrewrosindell', 13076),
#  ('hollylynch5', 13075),
#  ('jgray', 13048),
#  ('tandhesi', 12967),
#  ('emmalewellbuck', 12935),
#  ('amcarmichaelmp', 12931),
#  ('helengrantmp', 12807),
#  ('virendrasharma', 12709),
#  ('karenpbuckmp', 12699),
#  ('mariacaulfield', 12684),
#  ('iainastewart', 12606),
#  ('nickgibbuk', 12583),
#  ('davidmundelldct', 12528),
#  ('jamesduddridge', 12522),
#  ('gildernewm', 12521),
#  ('gradysnp', 12502),
#  ('elliereeves', 12494),
#  ('davidgauke', 12490),
#  ('chrisstephens', 12461),
#  ('paulmaynarduk', 12399),
#  ('annemilton', 12393),
#  ('margot_james_mp', 12370),
#  ('conormcginn', 12337),
#  ('richard4watford', 12332),
#  ('stephenctimms', 12317),
#  ('barrysheerman', 12300),
#  ('alexsobel', 12216),
#  ('nickherbertmp', 12211),
#  ('fitzmp', 12076),
#  ('nicdakinmp', 12015),
#  ('alecshelbrooke', 11961),
#  ('rehman_chishti', 11904),
#  ('pauljsweeney', 11868),
#  ('imran_hussainmp', 11861),
#  ('jennychapman', 11858),
#  ('gareththomasmp', 11839),
#  ('petergrantmp', 11796),
#  ('guyopperman', 11768),
#  ('vickyfoxcroft', 11697),
#  ('rosieduffield1', 11673),
#  ('deidrebrock', 11577),
#  ('rossthomson_mp', 11488),
#  ('carolinenokes', 11455),
#  ('geraintdaviesmp', 11444),
#  ('paulmaskeymp', 11426),
#  ('ajonesmp', 11363),
#  ('adamafriyie', 11361),
#  ('peterkyle', 11326),
#  ('vickyford', 11294),
#  ('willquince', 11277),
#  ('awmurrison', 11270),
#  ('mark4wyreforest', 11186),
#  ('angelacrawley30', 11185),
#  ('eastantrimmp', 11181),
#  ('henrysmithuk', 11153),
#  ('mark_spencer', 11099),
#  ('grahamstuart', 11084),
#  ('lindsayhoyle_mp', 10999),
#  ('ianclucas', 10979),
#  ('onnmel', 10951),
#  ('cliveefford', 10943),
#  ('little_pengelly', 10834),
#  ('drlisacameronmp', 10831),
#  ('emmahardymp', 10829),
#  ('aluncairns', 10821),
#  ('robertjenrick', 10749),
#  ('laboursj', 10749),
#  ('carolynharris24', 10712),
#  ('drewhendrysnp', 10690),
#  ('bbradleymp', 10680),
#  ('cherylgillan', 10641),
#  ('annietrev', 10620),
#  ('brendanoharasnp', 10611),
#  ('aloksharma_rdg', 10539),
#  ('anneliesedodds', 10510),
#  ('martinjdocherty', 10498),
#  ('dougchapmansnp', 10454),
#  ('mimsdavies', 10451),
#  ('justinmadders', 10445),
#  ('djwarburton', 10403),
#  ('rogergodsiff', 10378),
#  ('neilgraymp', 10340),
#  ('kemibadenoch', 10318),
#  ('marcusfysh', 10302),
#  ('kellytolhurst', 10264),
#  ('suehayman1', 10253),
#  ('davidrutley', 10251),
#  ('waynedavid_mp', 10176),
#  ('chrispincher', 10159),
#  ('jdjanogly', 10129),
#  ('chrishazzardsf', 10111),
#  ('marklancastermk', 10067),
#  ('kitmalthouse', 10037),
#  ('peter_dowd', 10028),
#  ('michael_ellis1', 10024),
#  ('walkerworcester', 9985),
#  ('bobblackman', 9953),
#  ('nus_ghani', 9924),
#  ('davidmorrisml', 9865),
#  ('lucyallan', 9846),
#  ('richardbenyonmp', 9835),
#  ('votepursglove', 9833),
#  ('gavnewlandssnp', 9814),
#  ('davidevennett', 9762),
#  ('jonathanplaid', 9753),
#  ('tpearce003', 9724),
#  ('mark_j_harper', 9670),
#  ('pgibsonsnp', 9647),
#  ('rosie4westlancs', 9532),
#  ('annamcmorrin', 9500),
#  ('ronniecowan', 9485),
#  ('stuart_mcdonald', 9470),
#  ('jeremylefroy', 9462),
#  ('grobinsondup', 9425),
#  ('lynbrownmp', 9394),
#  ('lsrplaid', 9249),
#  ('karenleemp', 9237),
#  ('marierimmer', 9056),
#  ('y_fovarguemp', 8981),
#  ('martinvickers', 8973),
#  ('chrism4chester', 8948),
#  ('nigelmp', 8907),
#  ('paulwilliamsmp', 8857),
#  ('crispinblunt', 8825),
#  ('alanbrownsnp', 8811),
#  ('mpritcharduk', 8798),
#  ('wera_hobhouse', 8727),
#  ('lisaforbes_', 8702),
#  ('s_hammond', 8584),
#  ('oletwinofficial', 8568),
#  ('mikekanemp', 8538),
#  ('marionfellows', 8522),
#  ('davidjonesmp', 8511),
#  ('michelledonelan', 8465),
#  ('toniaantoniazzi', 8461),
#  ('karinsmyth', 8343),
#  ('stevedouble', 8284),
#  ('huddlestonnigel', 8201),
#  ('rees4neath', 8200),
#  ('pow_rebecca', 8188),
#  ('madeleinemoon', 8140),
#  ('richardgrahamuk', 8102),
#  ('martyndaysnp', 8063),
#  ('judithcummins', 8020),
#  ('simon4ndorset', 7939),
#  ('jsheappey', 7882),
#  ('danirowley', 7879),
#  ('scullyp', 7855),
#  ('helen_whately', 7804),
#  ('claireperrymp', 7749),
#  ('seemakennedy', 7741),
#  ('gavinwilliamson', 7733),
#  ('huwmerriman', 7600),
#  ('davidlinden', 7580),
#  ('dunne4ludlow', 7563),
#  ('albertocostamp', 7473),
#  ('spellar', 7450),
#  ('peter_aldous', 7435),
#  ('jamesfrith', 7425),
#  ('jessicamordenmp', 7405),
#  ('gregknight', 7376),
#  ('william_wragg', 7258),
#  ('jeffsmithetc', 7250),
#  ('spelmanc', 7218),
#  ('cajardinemp', 7193),
#  ('simonclarkemp', 7175),
#  ('smcpartland', 7166),
#  ('michael4mdnp', 7157),
#  ('alanmakmp', 7156),
#  ('jackiedp', 7125),
#  ('cmackinlay', 7077),
#  ('hughgaffneymp', 7071),
#  ('kwasikwarteng', 7063),
#  ('neildotobrien', 7059),
#  ('hywelplaidcymru', 7051),
#  ('sandbach', 7042),
#  ('douglas4moray', 6991),
#  ('offord4hendon', 6945),
#  ('kevinhollinrake', 6942),
#  ('helenjonesmp', 6934),
#  ('victoriaprentis', 6917),
#  ('marcus4nuneaton', 6900),
#  ('jwhittingdale', 6890),
#  ('johnmcnallymp', 6884),
#  ('jochurchill4', 6879),
#  ('johnstevensonmp', 6849),
#  ('john2win', 6847),
#  ('annclwyd', 6809),
#  ('cpjelmore', 6773),
#  ('snewtonuk', 6773),
#  ('jc4southsuffolk', 6768),
#  ('pm4eastren', 6656),
#  ('cphilpofficial', 6649),
#  ('neill_bob', 6585),
#  ('alexchalkchelt', 6540),
#  ('bimafolami', 6504),
#  ('amandamilling', 6487),
#  ('cwhittakermp', 6474),
#  ('jamesmorris', 6439),
#  ('lee4ned', 6438),
#  ('robertsyms', 6361),
#  ('cgreenuk', 6337),
#  ('eleanor_smithmp', 6306),
#  ('julianknight15', 6295),
#  ('gordonmarsden', 6269),
#  ('janetdaby', 6236),
#  ('tony4rochdale', 6236),
#  ('morton_wendy', 6233),
#  ('albertowenmp', 6232),
#  ('bambosmp', 6217),
#  ('mikeamesburymp', 6206),
#  ('scottmann4nc', 6098),
#  ('blaenaugwentmp', 6005),
#  ('marktamimp', 6002),
#  ('nicktorfaenmp', 5992),
#  ('kirstene4angus', 5982),
#  ('maryrobinson01', 5961),
#  ('alanwhiteheadmp', 5950),
#  ('edwardleighmp', 5945),
#  ('thelma_walkermp', 5943),
#  ('simonhartmp', 5876),
#  ('davidedrew', 5839),
#  ('stephenlloydebn', 5803),
#  ('elishamcc_sf', 5735),
#  ('robertcourts', 5718),
#  ('stephenmorganmp', 5698),
#  ('craig4nwarks', 5647),
#  ('joplattmp', 5628),
#  ('jacklopresti', 5537),
#  ('glyndavies', 5458),
#  ('kate_hollernmp', 5381),
#  ('franciemolloy', 5345),
#  ('geraldjoneslab', 5333),
#  ('priskmark', 5331),
#  ('julieforburnley', 5305),
#  ('gareth_snell', 5240),
#  ('bwallacemp', 5217),
#  ('patrick4dales', 5200),
#  ('iowbobseely', 5198),
#  ('sandyofipswich', 5174),
#  ('redditchrachel', 5115),
#  ('lukegrahammp', 4974),
#  ('metcalfe_sbet', 4952),
#  ('markpawsey', 4946),
#  ('davidcrausby', 4903),
#  ('andrewbowiemp', 4896),
#  ('gilliankeegan', 4890),
#  ('kevin_j_foster', 4828),
#  ('stephenkerrmp', 4792),
#  ('rebeccaharrismp', 4724),
#  ('royston_smith', 4722),
#  ('gedk', 4666),
#  ('chrisevansmp', 4663),
#  ('derektwiggmp', 4613),
#  ('benmlake', 4612),
#  ('desmondswayne', 4607),
#  ('eddiehughes4wn', 4550),
#  ('jhowelluk', 4522),
#  ('lucyfrazermp', 4445),
#  ('mattwestern_', 4440),
#  ('susanelanjones', 4436),
#  ('lesleylaird', 4403),
#  ('orfhlaithbegley', 4332),
#  ('valerie_vazmp', 4260),
#  ('steph_peacock', 4254),
#  ('paulgirvanmp', 4218),
#  ('mikejwood', 4213),
#  ('oliverhealduk', 4139),
#  ('gillfurnissmp', 4100),
#  ('peternorthdevon', 4085),
#  ('nadams', 4084),
#  ('neil_parish', 4078),
#  ('jamie4north', 4008),
#  ('chris_ruanemp', 3949),
#  ('anorrismp', 3929),
#  ('brineminister', 3810),
#  ('khalid4pb', 3767),
#  ('johncryermp', 3747),
#  ('martwhitfieldmp', 3735),
#  ('alancampbellmp', 3718),
#  ('mickeybradysf', 3662),
#  ('fabianleedsne', 3644),
#  ('ruthnewportwest', 3644),
#  ('julialopezmp', 3630),
#  ('mattrodda', 3623),
#  ('leodochertyuk', 3587),
#  ('faisalrashid6', 3573),
#  ('mphendrick', 3538),
#  ('alewermbe', 3520),
#  ('nigelmills', 3344),
#  ('drcarolinej', 3306),
#  ('derekthomasuk', 3166),
#  ('davidsimpsondup', 3133),
#  ('adrianbaileymp', 3083),
#  ('kevinbarronmp', 2853),
#  ('ruthgeorge6', 2810),
#  ('garystreeterswd', 2774),
#  ('alexburghart', 2743),
#  ('lrobertsontewks', 2539),
#  ('davidduguidmp', 2446),
#  ('gileswatling', 2429),
#  ('jarrowstevemp', 2354),
#  ('eleanor4epping', 2211),
#  ('liztwistmp', 2211),
#  ('lukehall', 2193),
#  ('gutoaberconwy', 2166),
#  ('colin_j_clark', 2044),
#  ('jimshannonmp', 1923),
#  ('amessd_southend', 1904),
#  ('damienmooremp', 1904),
#  ('jimforcovsouth', 1772),
#  ('meljstride', 1636),
#  ('glindonmary', 1559),
#  ('mikehillmp', 1384),
#  ('geoffrey4covnw', 1331),
#  ('yasinmpbedford', 1275),
#  ('teamranil', 1200),
#  ('keithsimpsonmp', 1168),
#  ('jonathanlord', 1083),
#  ('richardbaconmp', 867),
#  ('houseofcommons', 570),
#  ('dodspeople', 570),
#  ('dt_pawlitical', 569),
#  ('commonslibrary', 564),
#  ('tweet_your_mp', 563),
#  ('davidhughespa', 563),
#  ('parlyapp', 563),
#  ('bbcdaniels', 560),
#  ('bestforbritain', 560),
#  ('randallstweet', 559),
#  ('keith_vaz_mp', 559),
#  ('thehouse_mag', 557),
#  ('centrallobby', 555),
#  ('johnbirdswords', 555),
#  ('owenjbennett', 553),
#  ('srtrc_england', 553),
#  ('ramsukpolitics', 552),
#  ('kc_political', 549),
#  ('alexjcharlton', 549),
#  ('hmd_uk', 548),
#  ('waspi_campaign', 547),
#  ('a50challenge', 547),
#  ('c4publicaffairs', 546),
#  ('labourwhips', 545),
#  ('appgsport', 544),
#  ('ipsauk', 543),
#  ('draxnews', 542),
#  ('sanjidaruhani', 539),
#  ('dpalliance', 539),
#  ('mark_stockwell', 537),
#  ('fdfcorpaffairs', 537),
#  ('benglaze', 536),
#  ('brettmasonnews', 535),
#  ('bbcalicia', 535),
#  ('cpa_uk', 535),
#  ('_katedevlin', 535),
#  ('loneshepherds', 534),
#  ('craigie_b', 532),
#  ('jarmstrong95', 531),
#  ('verified', 530),
#  ('james_northwood', 530),
#  ('coopukcampaigns', 530),
#  ('ctrobertthomas', 529),
#  ('kevinhiggins27', 528),
#  ('ranelaghuk', 527),
#  ('cbe_labour', 526),
#  ('mptranslation', 526),
#  ('matster2005', 525),
#  ('ryansabey', 525),
#  ('lornajane2', 525),
#  ('res_publica', 524),
#  ('samcarney15', 524),
#  ('faisalislam', 523),
#  ('owlsoflaughter', 522),
#  ('thegbhighst', 521),
#  ('aturnbull19931', 521),
#  ('joedphurst', 520),
#  ('jimignatowski2', 520),
#  ('clic_sargent', 520),
#  ('gmcgrathpr', 519),
#  ('appgyoungcancer', 518),
#  ('z7654321', 518),
#  ('natfednews', 517),
#  ('02waymana', 517),
#  ('triciaclough2', 517),
#  ('jackmyers94', 516),
#  ('ntextaffairs', 516),
#  ('clare_f', 515),
#  ('mencap_charity', 515),
#  ('graefox', 514),
#  ('postofficenews', 514),
#  ('eaglesbooks', 511),
#  ('paulbodman1', 510),
#  ('ovonewswire', 510),
#  ('factor8campaign', 509),
#  ('bennelmes', 508),
#  ('humanists_uk', 507),
#  ('lsepublicevents', 507),
#  ('bbcpress', 507),
#  ('pensionjustice', 506),
#  ('dannyhewitt221', 506),
#  ('nfutweets', 506),
#  ('jtmaclaren', 505),
#  ('ian_patrick', 505),
#  ('marki333', 505),
#  ('gingerbread', 505),
#  ('kerim_balci', 505),
#  ('rateyourleader', 504),
#  ('alan_mcguinness', 504),
#  ('sabinetyldesley', 502),
#  ('banderos', 502),
#  ('jawshwork', 501),
#  ('olliesayeed', 501),
#  ('appgbanking', 498),
#  ('kickstart_money', 498),
#  ('ejwardnews', 498),
#  ('thecommunityuk', 498),
#  ('louiesomerville', 497),
#  ('brickminster', 496),
#  ('lukey_stanger', 496),
#  ('paddy_m88', 496),
#  ('nordicdoor2', 495),
#  ('fairplaywomen', 495),
#  ('rosschawkins', 494),
#  ('elected_tech', 494),
#  ('emmdebee', 493),
#  ('jordon91buchan', 493),
#  ('ns_spotlight', 493),
#  ('isabelhardman', 493),
#  ('7030campaign', 493),
#  ('westlinkster', 493),
#  ('appgct', 492),
#  ('uk_music', 492),
#  ('georgeabrowning', 491),
#  ('peter25674', 491),
#  ('kashif_taher', 490),
#  ('emmawade89', 489),
#  ('sikhfeduk', 489),
#  ('yarhamj', 489),
#  ('westminsterpro', 488),
#  ('malalaw1', 488),
#  ('actiononmpabuse', 488),
#  ('moreuniteduk', 488),
#  ('stopbrexitmcg', 488),
#  ('vinnymcav', 488),
#  ('theresa_1vaa', 487),
#  ('loves__london', 487),
#  ('btbusinesscare', 486),
#  ('wizofoz17', 486),
#  ('frankpolitical', 486),
#  ('davit_pol', 486),
#  ('fcc_uk', 486),
#  ('joanne_bucci', 486),
#  ('pacumbria', 485),
#  ('meaningfulbloke', 485),
#  ('smiley_adam', 484),
#  ('nathan_sudworth', 484),
#  ('nccgod', 484),
#  ('zemblya', 483),
#  ('indparltrust', 483),
#  ('alstewitn', 483),
#  ('lordseconcom', 483),
#  ('mpsassistant', 483),
#  ('chris_goulden', 483),
#  ('greatbritain', 482),
#  ('rkwinvisibleman', 482),
#  ('be10percentgood', 480),
#  ('kelliecottam', 480),
#  ('rcsltpolicy', 480),
#  ('votersminute', 479),
#  ('bbcparliament', 479),
#  ('post_uk', 477),
#  ('icyminewsuk', 476),
#  ('kitty_donaldson', 476),
#  ('redcrosspolicy', 476),
#  ('gemcch', 475),
#  ('equalitytrust', 475),
#  ('roadfreightappg', 475),
#  ('dehavilland', 474),
#  ('ukyv', 474),
#  ('mogsymorg', 474),
#  ('schmooster', 473),
#  ('csol14441', 473),
#  ('gljlibdem', 473),
#  ('mattforde', 473),
#  ('prostateukvoice', 473),
#  ('neunion', 473),
#  ('barnettories', 472),
#  ('hocpress', 472),
#  ('nat_mem_arb', 471),
#  ('britishmuseum', 470),
#  ('thecommonfairy', 470),
#  ('rowantni', 470),
#  ('ianmaiden2', 469),
#  ('bringbackbr', 468),
#  ('antibullyingpro', 467),
#  ('janemerrick23', 467),
#  ('thersipus', 467),
#  ('dotasscandal', 467),
#  ('argyle_alys', 466),
#  ('thelpdf', 466),
#  ('timbarclay_grab', 466),
#  ('mrdanieledward', 466),
#  ('hansardsociety', 466),
#  ('calum_masters', 466),
#  ('imi_ahmed', 466),
#  ('phairo', 466),
#  ('watchdogmichael', 465),
#  ('peterh86', 465),
#  ('ladpolitics', 465),
#  ('tog4policy', 464),
#  ('euractivuk', 464),
#  ('charityretail', 464),
#  ('fundingcircle', 463),
#  ('kajentapps', 463),
#  ('dodsevents', 463),
#  ('averagemp', 462),
#  ('macmillanpa', 462),
#  ('kulganofcrydee', 462),
#  ('domwilliamson13', 462),
#  ('peterh220486', 462),
#  ('papworthpolicy', 461),
#  ('political_con', 461),
#  ('rewearmouth', 461),
#  ('tejaschandarana', 461),
#  ('__interfaith__', 461),
#  ('fairtaxonflying', 461),
#  ('cavendishpc', 461),
#  ('seanblog2017', 461),
#  ('lizzybuchan', 460),
#  ('chrisdod1', 460),
#  ('policy_exchange', 460),
#  ('boden_will', 460),
#  ('naoorguk', 460),
#  ('ukdefjournal', 460),
#  ('rowenamason', 459),
#  ('loanchargeappg', 459),
#  ('hgale15', 459),
#  ('liamcbedford', 459),
#  ('dwclark79', 459),
#  ('apprenticeappg', 459),
#  ('childsocpol', 459),
#  ('makeuk_', 459),
#  ('chrleftni', 459),
#  ('ukmps1', 458),
#  ('johnestevens', 458),
#  ('apdawg1', 458),
#  ('alcatone', 458),
#  ('oscarmurphy100', 457),
#  ('adamellisleach', 457),
#  ('cpadvocacy', 457),
#  ('pbconsultinguk', 457),
#  ('brexpatsappg', 457),
#  ('hearmemp', 457),
#  ('highwaycodegb', 456),
#  ('nfrn_online', 456),
#  ('representlive', 456),
#  ('martinbeckford', 455),
#  ('thercn', 455),
#  ('arcadisuk', 455),
#  ('skeeaats', 455),
#  ('uk_francine', 454),
#  ('smartenergygb', 454),
#  ('fdsaussure', 453),
#  ('official_mrlp', 453),
#  ('joerukin', 453),
#  ('iainjwatson', 453),
#  ('pupaid', 453),
#  ('caabu', 453),
#  ('adhdaction', 453),
#  ('assemblywales', 453),
#  ('sebastianhanley', 452),
#  ('ukgenelection', 452),
#  ('jackrich93', 452),
#  ('monitoremail', 452),
#  ('grohokopal', 452),
#  ('candsalliance', 452),
#  ('bsta1979', 451),
#  ('fatbazza1981', 451),
#  ('humansrealhuman', 451),
#  ('pinchmeplato', 451),
#  ('macemagazine', 451),
#  ('aoc_info', 451),
#  ('aphillips_2014', 451),
#  ('factionvideo', 451),
#  ('talktalkgroup', 451),
#  ('phillyerwhite', 451),
#  ('meritocracyni', 451),
#  ('sebbutton', 451),
#  ('alexandercraig_', 451),
#  ('creditservicesa', 451),
#  ('comaweng', 450),
#  ('cctvincare', 450),
#  ('hmrc_taxthieves', 450),
#  ('daveunspun', 450),
#  ('streetgames', 450),
#  ('jtoriordan', 450),
#  ('integrationappg', 450),
#  ('speakerbercow', 449),
#  ('lcf_admin', 449),
#  ('vapingfreedom', 449),
#  ('hinterlandtweet', 449),
#  ('fixbritinternet', 449),
#  ('stop35k', 449),
#  ('chrisg0000', 448),
#  ('tariqbnp', 448),
#  ('jshood52', 448),
#  ('davidatkins7642', 448),
#  ('g_grev', 448),
#  ('adolphusduru_', 448),
#  ('ilaindia', 448),
#  ('richardpreston_', 448),
#  ('leggy_1', 448),
#  ('dsp4today', 447),
#  ('dontscreenusout', 447),
#  ('heyholyroller', 447),
#  ('ibnalafriki', 447),
#  ('fairprice4care', 447),
#  ('timbuctooo', 446),
#  ('arthur_clarky', 446),
#  ('hocwatch', 446),
#  ('pistolsback_', 446),
#  ('ayestotheright', 446),
#  ('budfrog', 446),
#  ('jakethurmanuk', 445),
#  ('pauljchurch', 445),
#  ('wheredothey', 445),
#  ('graymf1', 445),
#  ('thesecretwonk', 444),
#  ('mpwatcher', 444),
#  ('theonealexg', 444),
#  ('mrandymurray', 444),
#  ('hannah_mcgrath', 444),
#  ('dodsmonitoring', 443),
#  ('mpwatchers', 443),
#  ('christopherhope', 443),
#  ('thechildofroth', 443),
#  ('pdcparliament', 443),
#  ('neoaustin69', 442),
#  ('pd_politics', 442),
#  ('ofoma3', 442),
#  ('heartvalvevoice', 442),
#  ('gingerbreadpa', 441),
#  ('behereformeuk', 441),
#  ('foodrev', 440),
#  ('bpva', 440),
#  ('vote_football', 440),
#  ('jpwtaylor', 440),
#  ('manonabus1', 439),
#  ('evolvepolitics', 439),
#  ('zobayer_mahamud', 439),
#  ('saskiaabdoh', 439),
#  ('referendometer', 439),
#  ('edwardlucas', 438),
#  ('citizenshipbrit', 438),
#  ('north_landwaspi', 438),
#  ('rmehmood', 438),
#  ('jkweaver1', 437),
#  ('braintumourorg', 437),
#  ('dan_splaining', 437),
#  ('francis_macombe', 437),
#  ('parliamentrview', 435),
#  ('waspi_campaign_', 435),
#  ('joshryandavis', 435),
#  ('nutonline', 434),
#  ('polstudiesassoc', 434),
#  ('efta4uk', 434),
#  ('vivergofuels', 434),
#  ('jamesoleary2020', 433),
#  ('cutsvote', 433),
#  ('hrryh_', 433),
#  ('ba1dr1ck', 433),
#  ('swissembassyuk', 432),
#  ('mejobest', 432),
#  ('fatherlessf8', 432),
#  ('cfahelen', 432),
#  ('sra_solicitors', 431),
#  ('samueljenkinson', 431),
#  ('steffanyohannes', 430),
#  ('apgif', 430),
#  ('nahidvicky', 430),
#  ('fefocus', 430),
#  ('cuttinmaurizio', 429),
#  ('fmbuilders', 429),
#  ('jamesrowlands', 429),
#  ('lee_georgina', 429),
#  ('quickpmqs', 428),
#  ('appgbioethanol', 428),
#  ('end_our_pain', 428),
#  ('moandtaff', 427),
#  ('parlylingo', 426),
#  ('alistair_dewar_', 426),
#  ('0xbeefcafe', 426),
#  ('lgacomms', 426),
#  ('smugmp', 426),
#  ('jackdawinfo', 426),
#  ('soundsleg1t', 425),
#  ('spenthomf', 425),
#  ('sedwards1976', 425),
#  ('gb_takeaway', 425),
#  ('matthewlongmuir', 424),
#  ('bdnews24', 423),
#  ('craigawoodhouse', 423),
#  ('gavinbarwell', 423),
#  ('politinsight', 423),
#  ('mp_rt', 423),
#  ('mjriddleston', 422),
#  ('bermy187', 422),
#  ('joe_chrisp', 421),
#  ('mksands', 421),
#  ('kieranrnash', 421),
#  ('ashleahskinner', 420),
#  ('laura_k_hughes', 420),
#  ('legalobservers', 420),
#  ('cavendishfuture', 420),
#  ('gus_baldwin', 419),
#  ('malcfleming', 419),
#  ('leaguepolitical', 419),
#  ('harrisonkt_', 419),
#  ('paulwaugh', 419),
#  ('gjccooper', 418),
#  ('hanover_health', 418),
#  ('justintime2359', 418),
#  ('josephwillits', 418),
#  ('lorraineteuten', 417),
#  ('labour1969', 417),
#  ('iicsamrsas', 417),
#  ('willwoodwardai', 417),
#  ('osinakachiakuma', 417),
#  ('paulewinston', 416),
#  ('_jpard', 415),
#  ('nathansbennett', 415),
#  ('verster', 415),
#  ('seph1812', 415),
#  ('georginarosen', 414),
#  ('kpsinnowhere', 414),
#  ('uknoel', 414),
#  ('anderson11115', 414),
#  ('bhfpolicy', 414),
#  ('stjohnambulance', 414),
#  ('charlesmaggs', 413),
#  ('eloisetodd', 413),
#  ('itexistsuk', 413),
#  ('holocaustuk', 412),
#  ('tanni_gt', 412),
#  ...]
